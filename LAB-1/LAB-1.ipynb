# %% [markdown]
# ## LAB-1: Installing Qiskit and setting up the environment

# %% [markdown]
# ## Name: Neelanjan Dutta

# %% [markdown]
# ## Register number: 2448040

# %% [markdown]
# ## Installing Qiksit:

# %%
# !pip install qiskit
# Out:
# ...
# The current version of qiskit is: 2.1.2

# %% [markdown]
# ## Checking whether qiskit is installed or not:

# %%
import qiskit

# %% [markdown]
# ## Checking the version of qiskit:

# %%
v = qiskit.__version__
print("The current version of qiskit is:" , v)
# Out:
# The current version of qiskit is: 2.1.2

# %% [markdown]
# ## A sample example:

# %%
from IPython.display import display
from qiskit import QuantumCircuit
# Create a simple quantum circuit
qc = QuantumCircuit(1, 1)   # 1 qubit, 1 classical bit
qc.x(0)                     # Apply NOT (X) gate
qc.measure(0, 0)            # Measure qubit
display(qc.draw('mpl')) # Explicitly display the drawing

# %% [markdown]
# The time complexity of the above code is O(1)
